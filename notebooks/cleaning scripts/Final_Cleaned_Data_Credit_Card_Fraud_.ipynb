# %% [markdown]
# # Credit Card Fraud Dataset Cleaning
# This notebook performs data cleaning steps suitable for ML and forecasting.

# %%
import pandas as pd
# Load the dataset
df = pd.read_csv("/content/credit_card_fraud.csv")
print(df)
df.head()
# Out:
#             Time         V1         V2        V3        V4        V5  \
# 0            0.0  -1.359807  -0.072781  2.536347  1.378155 -0.338321
# 1            0.0   1.191857   0.266151  0.166480  0.448154  0.060018
# 2            1.0  -1.358354  -1.340163  1.773209  0.379780 -0.503198
# 3            1.0  -0.966272  -0.185226  1.792993 -0.863291 -0.010309
# 4            2.0  -1.158233   0.877737  1.548718  0.403034 -0.407193
# ...          ...        ...        ...       ...       ...       ...
# 284802  172786.0 -11.881118  10.071785 -9.834783 -2.066656 -5.364473
# 284803  172787.0  -0.732789  -0.055080  2.035030 -0.738589  0.868229
# 284804  172788.0   1.919565  -0.301254 -3.249640 -0.557828  2.630515
# 284805  172788.0  -0.240440   0.530483  0.702510  0.689799 -0.377961
# 284806  172792.0  -0.533413  -0.189733  0.703337 -0.506271 -0.012546
#
#               V6        V7        V8        V9  ...       V21       V22  \
# 0       0.462388  0.239599  0.098698  0.363787  ... -0.018307  0.277838
# 1      -0.082361 -0.078803  0.085102 -0.255425  ... -0.225775 -0.638672
# 2       1.800499  0.791461  0.247676 -1.514654  ...  0.247998  0.771679
# 3       1.247203  0.237609  0.377436 -1.387024  ... -0.108300  0.005274
# 4       0.095921  0.592941 -0.270533  0.817739  ... -0.009431  0.798278
# ...          ...       ...       ...       ...  ...       ...       ...
# 284802 -2.606837 -4.918215  7.305334  1.914428  ...  0.213454  0.111864
# 284803  1.058415  0.024330  0.294869  0.584800  ...  0.214205  0.924384
# 284804  3.031260 -0.296827  0.708417  0.432454  ...  0.232045  0.578229
# 284805  0.623708 -0.686180  0.679145  0.392087  ...  0.265245  0.800049
# 284806 -0.649617  1.577006 -0.414650  0.486180  ...  0.261057  0.643078
#
#              V23       V24       V25       V26       V27       V28  Amount  \
# 0      -0.110474  0.066928  0.128539 -0.189115  0.133558 -0.021053  149.62
# 1       0.101288 -0.339846  0.167170  0.125895 -0.008983  0.014724    2.69
# 2       0.909412 -0.689281 -0.327642 -0.139097 -0.055353 -0.059752  378.66
# 3      -0.190321 -1.175575  0.647376 -0.221929  0.062723  0.061458  123.50
# 4      -0.137458  0.141267 -0.206010  0.502292  0.219422  0.215153   69.99
# ...          ...       ...       ...       ...       ...       ...     ...
# 284802  1.014480 -0.509348  1.436807  0.250034  0.943651  0.823731    0.77
# 284803  0.012463 -1.016226 -0.606624 -0.395255  0.068472 -0.053527   24.79
# 284804 -0.037501  0.640134  0.265745 -0.087371  0.004455 -0.026561   67.88
# 284805 -0.163298  0.123205 -0.569159  0.546668  0.108821  0.104533   10.00
# 284806  0.376777  0.008797 -0.473649 -0.818267 -0.002415  0.013649  217.00
#
#         Class
# 0           0
# 1           0
# 2           0
# 3           0
# 4           0
# ...       ...
# 284802      0
# 284803      0
# 284804      0
# 284805      0
# 284806      0
#
# [284807 rows x 31 columns]

# %%
# Step 1: Remove duplicates
df = df.drop_duplicates()
print(f"Shape after removing duplicates: {df.shape}")
# Out:
# Shape after removing duplicates: (283726, 31)

# %%
# Step 2: Check for missing/null values
missing = df.isnull().sum().sum()
print(f"Total missing values: {missing}")
# Out:
# Total missing values: 0

# %%
# Step 3: Remove outliers using IQR
def remove_outliers_iqr(dataframe, columns):
    for col in columns:
        Q1 = dataframe[col].quantile(0.25)
        Q3 = dataframe[col].quantile(0.75)
        IQR = Q3 - Q1
        lower = Q1 - 1.5 * IQR
        upper = Q3 + 1.5 * IQR
        dataframe = dataframe[(dataframe[col] >= lower) & (dataframe[col] <= upper)]
    return dataframe

df = remove_outliers_iqr(df, ['Amount', 'Time'])
print(f"Shape after outlier removal: {df.shape}")
# Out:
# Shape after outlier removal: (252041, 31)

# %%
# Step 4: Save cleaned dataset
df.to_csv("credit_card_fraud_cleaned.csv", index=False)
print("Cleaned dataset saved as 'credit_card_fraud_cleaned.csv'")
# Out:
# Cleaned dataset saved as 'credit_card_fraud_cleaned.csv'

# %%
cdf = pd.read_csv("/content/credit_card_fraud_cleaned.csv")
print(cdf)
cdf.head()
# Out:
#             Time         V1         V2        V3        V4        V5  \
# 0            0.0  -1.359807  -0.072781  2.536347  1.378155 -0.338321
# 1            0.0   1.191857   0.266151  0.166480  0.448154  0.060018
# 2            1.0  -0.966272  -0.185226  1.792993 -0.863291 -0.010309
# 3            2.0  -1.158233   0.877737  1.548718  0.403034 -0.407193
# 4            2.0  -0.425966   0.960523  1.141109 -0.168252  0.420987
# ...          ...        ...        ...       ...       ...       ...
# 252036  172785.0   0.120316   0.931005 -0.546012 -0.745097  1.130314
# 252037  172786.0 -11.881118  10.071785 -9.834783 -2.066656 -5.364473
# 252038  172787.0  -0.732789  -0.055080  2.035030 -0.738589  0.868229
# 252039  172788.0   1.919565  -0.301254 -3.249640 -0.557828  2.630515
# 252040  172788.0  -0.240440   0.530483  0.702510  0.689799 -0.377961
#
#               V6        V7        V8        V9  ...       V21       V22  \
# 0       0.462388  0.239599  0.098698  0.363787  ... -0.018307  0.277838
# 1      -0.082361 -0.078803  0.085102 -0.255425  ... -0.225775 -0.638672
# 2       1.247203  0.237609  0.377436 -1.387024  ... -0.108300  0.005274
# 3       0.095921  0.592941 -0.270533  0.817739  ... -0.009431  0.798278
# 4      -0.029728  0.476201  0.260314 -0.568671  ... -0.208254 -0.559825
# ...          ...       ...       ...       ...  ...       ...       ...
# 252036 -0.235973  0.812722  0.115093 -0.204064  ... -0.314205 -0.808520
# 252037 -2.606837 -4.918215  7.305334  1.914428  ...  0.213454  0.111864
# 252038  1.058415  0.024330  0.294869  0.584800  ...  0.214205  0.924384
# 252039  3.031260 -0.296827  0.708417  0.432454  ...  0.232045  0.578229
# 252040  0.623708 -0.686180  0.679145  0.392087  ...  0.265245  0.800049
#
#              V23       V24       V25       V26       V27       V28  Amount  \
# 0      -0.110474  0.066928  0.128539 -0.189115  0.133558 -0.021053  149.62
# 1       0.101288 -0.339846  0.167170  0.125895 -0.008983  0.014724    2.69
# 2      -0.190321 -1.175575  0.647376 -0.221929  0.062723  0.061458  123.50
# 3      -0.137458  0.141267 -0.206010  0.502292  0.219422  0.215153   69.99
# 4      -0.026398 -0.371427 -0.232794  0.105915  0.253844  0.081080    3.67
# ...          ...       ...       ...       ...       ...       ...     ...
# 252036  0.050343  0.102800 -0.435870  0.124079  0.217940  0.068803    2.69
# 252037  1.014480 -0.509348  1.436807  0.250034  0.943651  0.823731    0.77
# 252038  0.012463 -1.016226 -0.606624 -0.395255  0.068472 -0.053527   24.79
# 252039 -0.037501  0.640134  0.265745 -0.087371  0.004455 -0.026561   67.88
# 252040 -0.163298  0.123205 -0.569159  0.546668  0.108821  0.104533   10.00
#
#         Class
# 0           0
# 1           0
# 2           0
# 3           0
# 4           0
# ...       ...
# 252036      0
# 252037      0
# 252038      0
# 252039      0
# 252040      0
#
# [252041 rows x 31 columns]
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 3   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
# 4   2.0 -0.425966  0.960523  1.141109 -0.168252  0.420987 -0.029728  0.476201
#
#          V8        V9  ...       V21       V22       V23       V24       V25  \
# 0  0.098698  0.363787  ... -0.018307  0.277838 -0.110474  0.066928  0.128539
# 1  0.085102 -0.255425  ... -0.225775 -0.638672  0.101288 -0.339846  0.167170
# 2  0.377436 -1.387024  ... -0.108300  0.005274 -0.190321 -1.175575  0.647376
# 3 -0.270533  0.817739  ... -0.009431  0.798278 -0.137458  0.141267 -0.206010
# 4  0.260314 -0.568671  ... -0.208254 -0.559825 -0.026398 -0.371427 -0.232794
#
#         V26       V27       V28  Amount  Class
# 0 -0.189115  0.133558 -0.021053  149.62      0
# 1  0.125895 -0.008983  0.014724    2.69      0
# 2 -0.221929  0.062723  0.061458  123.50      0
# 3  0.502292  0.219422  0.215153   69.99      0
# 4  0.105915  0.253844  0.081080    3.67      0
#
# [5 rows x 31 columns]
